# %% [markdown]
# A bookstore wants to analyze book sales over a specified period to determine whether sales are increasing, decreasing, or remaining stable.
#
# Your task is to investigate book sales for each 6-month period ending in March, April, and May of 2024. For example, when analyzing March, include the sales for March plus the preceding 5 months. The March 2024 analysis should include sales from October 1, 2023, to March 31, 2024, and similarly for April and May.
#
# Calculate the total number of books sold for each analyzed period and identify the most popular book sold during that period.
#
# For this task, you are provided with two datasets: one containing book sales data from 2021 to 2024, and the other containing the specific periods of time that require analysis.

# %% [markdown]
# ### Importing libraries and data

# %%
import pandas as pd
import numpy as np
import os

path = r'C:\Users\LeLuu\Documents\Python_Practice\challenge_427'

book_sales = pd.read_csv(os.path.join('Book Sales.csv'), index_col=False)
periods = pd.read_csv(os.path.join('Time Periods.csv'), index_col=False)

# %% [markdown]
# ### Data Validation

# %%
book_sales.head()
# Out:
#          Date          BookTitle
# 0  2024-01-01  Lord of the Flies
# 1  2024-01-01               1984
# 2  2024-01-01  Lord of the Flies
# 3  2024-01-01               1984
# 4  2024-01-01   The Great Gatsby

# %%
book_sales.dtypes
# Out:
# Date         object
# BookTitle    object
# dtype: object

# %%
book_sales.value_counts()
# Out:
# Date        BookTitle
# 2024-02-05  The Great Gatsby          44
# 2024-05-23  To Kil A Mockingbird      38
# 2024-02-02  The Catcher in the Rye    37
# 2024-05-19  Crime and Punishment      37
# 2024-02-10  Lord of the Flies         37
#                                       ..
# 2023-02-25  1984                       1
# 2022-12-04  The Corrections            1
#             To Kil A Mockingbird       1
# 2022-12-05  Crime and Punishment       1
# 2022-08-03  Lord of the Flies          1
# Name: count, Length: 4553, dtype: int64

# %%
periods.head()
# Out:
#     Start_YMD     End_YMD  MonthToReport
# 0  2023-12-01  2024-05-31              1
# 1  2023-11-01  2024-04-30              2
# 2  2023-10-01  2024-03-31              3

# %%
periods.dtypes
# Out:
# Start_YMD        object
# End_YMD          object
# MonthToReport     int64
# dtype: object

# %% [markdown]
# ### Solving the Challenge

# %%
#Convert the Date to Datetime data type
book_sales['Date'] = pd.to_datetime(book_sales['Date'])

# %%
#Convert both Start_YMD and End_YMD to Datetime data type
periods['Start_YMD'] = pd.to_datetime(periods['Start_YMD'])
periods['End_YMD'] = pd.to_datetime(periods['End_YMD'])

# %%
#Should check if Date is in the range of Start_YMD and End_YMD => use Cross Join
combine_data = pd.merge(book_sales,periods,how='cross')
combine_data
# Out:
#              Date               BookTitle  Start_YMD    End_YMD  MonthToReport
# 0      2024-01-01       Lord of the Flies 2023-12-01 2024-05-31              1
# 1      2024-01-01       Lord of the Flies 2023-11-01 2024-04-30              2
# 2      2024-01-01       Lord of the Flies 2023-10-01 2024-03-31              3
# 3      2024-01-01                    1984 2023-12-01 2024-05-31              1
# 4      2024-01-01                    1984 2023-11-01 2024-04-30              2
# ...           ...                     ...        ...        ...            ...
# 182500 2022-12-31        The Great Gatsby 2023-11-01 2024-04-30              2
# 182501 2022-12-31        The Great Gatsby 2023-10-01 2024-03-31              3
# 182502 2022-12-31  The Catcher in the Rye 2023-12-01 2024-05-31              1
# 182503 2022-12-31  The Catcher in the Rye 2023-11-01 2024-04-30              2
# 182504 2022-12-31  The Catcher in the Rye 2023-10-01 2024-03-31              3
#
# [182505 rows x 5 columns]

# %%
#Add a filter to check if Date is in Range, if true returns T otherwise returns F
combine_data['filter'] = combine_data.apply(
    lambda row: "T" if row['Start_YMD'] <= row['Date'] <= row['End_YMD'] else "F",
    axis=1
)

# %%
combine_data
# Out:
#              Date               BookTitle  Start_YMD    End_YMD  \
# 0      2024-01-01       Lord of the Flies 2023-12-01 2024-05-31
# 1      2024-01-01       Lord of the Flies 2023-11-01 2024-04-30
# 2      2024-01-01       Lord of the Flies 2023-10-01 2024-03-31
# 3      2024-01-01                    1984 2023-12-01 2024-05-31
# 4      2024-01-01                    1984 2023-11-01 2024-04-30
# ...           ...                     ...        ...        ...
# 182500 2022-12-31        The Great Gatsby 2023-11-01 2024-04-30
# 182501 2022-12-31        The Great Gatsby 2023-10-01 2024-03-31
# 182502 2022-12-31  The Catcher in the Rye 2023-12-01 2024-05-31
# 182503 2022-12-31  The Catcher in the Rye 2023-11-01 2024-04-30
# 182504 2022-12-31  The Catcher in the Rye 2023-10-01 2024-03-31
#
#         MonthToReport filter
# 0                   1      T
# 1                   2      T
# 2                   3      T
# 3                   1      T
# 4                   2      T
# ...               ...    ...
# 182500              2      F
# 182501              3      F
# 182502              1      F
# 182503              2      F
# 182504              3      F
#
# [182505 rows x 6 columns]

# %%
#Group by Start, End YMD, filter and count the filter,
in_range_filter = combine_data.groupby(by=['Start_YMD','End_YMD','filter']).agg(AllBookSalesInDateRange=('filter','count')).reset_index()

# %%
in_range_filter
# Out:
#    Start_YMD    End_YMD filter  AllBookSalesInDateRange
# 0 2023-10-01 2024-03-31      F                    31660
# 1 2023-10-01 2024-03-31      T                    29175
# 2 2023-11-01 2024-04-30      F                    30394
# 3 2023-11-01 2024-04-30      T                    30441
# 4 2023-12-01 2024-05-31      F                    29437
# 5 2023-12-01 2024-05-31      T                    31398

# %%
#only get the T value in filter
in_range_filter = in_range_filter[in_range_filter['filter']=='T']

# %%
in_range_filter
# Out:
#    Start_YMD    End_YMD filter  AllBookSalesInDateRange
# 1 2023-10-01 2024-03-31      T                    29175
# 3 2023-11-01 2024-04-30      T                    30441
# 5 2023-12-01 2024-05-31      T                    31398

# %%
#count number of book sold in the date range
#group by start ymd, end ymd, filter and book title, count book title
books_sold = combine_data.groupby(by=['Start_YMD','End_YMD','filter','BookTitle']).agg(BookTitleSalesInDateRange=('BookTitle','count')).reset_index()

# %%
books_sold
# Out:
#     Start_YMD    End_YMD filter               BookTitle  \
# 0  2023-10-01 2024-03-31      F                    1984
# 1  2023-10-01 2024-03-31      F    Crime and Punishment
# 2  2023-10-01 2024-03-31      F       Lord of the Flies
# 3  2023-10-01 2024-03-31      F  The Catcher in the Rye
# 4  2023-10-01 2024-03-31      F         The Corrections
# 5  2023-10-01 2024-03-31      F        The Great Gatsby
# 6  2023-10-01 2024-03-31      F   The Lord of the Rings
# 7  2023-10-01 2024-03-31      F    To Kil A Mockingbird
# 8  2023-10-01 2024-03-31      T                    1984
# 9  2023-10-01 2024-03-31      T    Crime and Punishment
# 10 2023-10-01 2024-03-31      T       Lord of the Flies
# 11 2023-10-01 2024-03-31      T  The Catcher in the Rye
# 12 2023-10-01 2024-03-31      T         The Corrections
# 13 2023-10-01 2024-03-31      T        The Great Gatsby
# 14 2023-10-01 2024-03-31      T   The Lord of the Rings
# 15 2023-10-01 2024-03-31      T    To Kil A Mockingbird
# 16 2023-11-01 2024-04-30      F                    1984
# 17 2023-11-01 2024-04-30      F    Crime and Punishment
# 18 2023-11-01 2024-04-30      F       Lord of the Flies
# 19 2023-11-01 2024-04-30      F  The Catcher in the Rye
# 20 2023-11-01 2024-04-30      F         The Corrections
# 21 2023-11-01 2024-04-30      F        The Great Gatsby
# 22 2023-11-01 2024-04-30      F   The Lord of the Rings
# 23 2023-11-01 2024-04-30      F    To Kil A Mockingbird
# 24 2023-11-01 2024-04-30      T                    1984
# 25 2023-11-01 2024-04-30      T    Crime and Punishment
# 26 2023-11-01 2024-04-30      T       Lord of the Flies
# 27 2023-11-01 2024-04-30      T  The Catcher in the Rye
# 28 2023-11-01 2024-04-30      T         The Corrections
# 29 2023-11-01 2024-04-30      T        The Great Gatsby
# 30 2023-11-01 2024-04-30      T   The Lord of the Rings
# 31 2023-11-01 2024-04-30      T    To Kil A Mockingbird
# 32 2023-12-01 2024-05-31      F                    1984
# 33 2023-12-01 2024-05-31      F    Crime and Punishment
# 34 2023-12-01 2024-05-31      F       Lord of the Flies
# 35 2023-12-01 2024-05-31      F  The Catcher in the Rye
# 36 2023-12-01 2024-05-31      F         The Corrections
# 37 2023-12-01 2024-05-31      F        The Great Gatsby
# 38 2023-12-01 2024-05-31      F   The Lord of the Rings
# 39 2023-12-01 2024-05-31      F    To Kil A Mockingbird
# 40 2023-12-01 2024-05-31      T                    1984
# 41 2023-12-01 2024-05-31      T    Crime and Punishment
# 42 2023-12-01 2024-05-31      T       Lord of the Flies
# 43 2023-12-01 2024-05-31      T  The Catcher in the Rye
# 44 2023-12-01 2024-05-31      T         The Corrections
# 45 2023-12-01 2024-05-31      T        The Great Gatsby
# 46 2023-12-01 2024-05-31      T   The Lord of the Rings
# 47 2023-12-01 2024-05-31      T    To Kil A Mockingbird
#
#     BookTitleSalesInDateRange
# 0                        3902
# 1                        4035
# 2                        4016
# 3                        3930
# 4                        3959
# 5                        3922
# 6                        3957
# 7                        3939
# 8                        3550
# 9                        3683
# 10                       3681
# 11                       3663
# 12                       3689
# 13                       3685
# 14                       3590
# 15                       3634
# 16                       3757
# 17                       3916
# 18                       3825
# 19                       3797
# 20                       3818
# 21                       3734
# 22                       3755
# 23                       3792
# 24                       3695
# 25                       3802
# 26                       3872
# 27                       3796
# 28                       3830
# 29                       3873
# 30                       3792
# 31                       3781
# 32                       3668
# 33                       3807
# 34                       3704
# 35                       3666
# 36                       3701
# 37                       3642
# 38                       3575
# 39                       3674
# 40                       3784
# 41                       3911
# 42                       3993
# 43                       3927
# 44                       3947
# 45                       3965
# 46                       3972
# 47                       3899

# %%
#filter to return only if in range filter is T
book_sold_in_range = books_sold[books_sold['filter']=='T']

# %%
book_sold_in_range
# Out:
#     Start_YMD    End_YMD filter               BookTitle  \
# 8  2023-10-01 2024-03-31      T                    1984
# 9  2023-10-01 2024-03-31      T    Crime and Punishment
# 10 2023-10-01 2024-03-31      T       Lord of the Flies
# 11 2023-10-01 2024-03-31      T  The Catcher in the Rye
# 12 2023-10-01 2024-03-31      T         The Corrections
# 13 2023-10-01 2024-03-31      T        The Great Gatsby
# 14 2023-10-01 2024-03-31      T   The Lord of the Rings
# 15 2023-10-01 2024-03-31      T    To Kil A Mockingbird
# 24 2023-11-01 2024-04-30      T                    1984
# 25 2023-11-01 2024-04-30      T    Crime and Punishment
# 26 2023-11-01 2024-04-30      T       Lord of the Flies
# 27 2023-11-01 2024-04-30      T  The Catcher in the Rye
# 28 2023-11-01 2024-04-30      T         The Corrections
# 29 2023-11-01 2024-04-30      T        The Great Gatsby
# 30 2023-11-01 2024-04-30      T   The Lord of the Rings
# 31 2023-11-01 2024-04-30      T    To Kil A Mockingbird
# 40 2023-12-01 2024-05-31      T                    1984
# 41 2023-12-01 2024-05-31      T    Crime and Punishment
# 42 2023-12-01 2024-05-31      T       Lord of the Flies
# 43 2023-12-01 2024-05-31      T  The Catcher in the Rye
# 44 2023-12-01 2024-05-31      T         The Corrections
# 45 2023-12-01 2024-05-31      T        The Great Gatsby
# 46 2023-12-01 2024-05-31      T   The Lord of the Rings
# 47 2023-12-01 2024-05-31      T    To Kil A Mockingbird
#
#     BookTitleSalesInDateRange
# 8                        3550
# 9                        3683
# 10                       3681
# 11                       3663
# 12                       3689
# 13                       3685
# 14                       3590
# 15                       3634
# 24                       3695
# 25                       3802
# 26                       3872
# 27                       3796
# 28                       3830
# 29                       3873
# 30                       3792
# 31                       3781
# 40                       3784
# 41                       3911
# 42                       3993
# 43                       3927
# 44                       3947
# 45                       3965
# 46                       3972
# 47                       3899

# %%
#group by the start ymd and end ymd, find the max of booktitlesalesindaterange
highest_books = book_sold_in_range.loc[
    book_sold_in_range.groupby(['Start_YMD', 'End_YMD'])['BookTitleSalesInDateRange'].idxmax()
]

# %%
highest_books
# Out:
#     Start_YMD    End_YMD filter          BookTitle  BookTitleSalesInDateRange
# 12 2023-10-01 2024-03-31      T    The Corrections                       3689
# 29 2023-11-01 2024-04-30      T   The Great Gatsby                       3873
# 42 2023-12-01 2024-05-31      T  Lord of the Flies                       3993

# %%
result = pd.merge(in_range_filter,highest_books,on=['Start_YMD','End_YMD'],how='inner')[['Start_YMD','End_YMD','AllBookSalesInDateRange','BookTitle','BookTitleSalesInDateRange']]

# %%
result.sort_values(by='Start_YMD',ascending=False)
# Out:
#    Start_YMD    End_YMD  AllBookSalesInDateRange          BookTitle  \
# 2 2023-12-01 2024-05-31                    31398  Lord of the Flies
# 1 2023-11-01 2024-04-30                    30441   The Great Gatsby
# 0 2023-10-01 2024-03-31                    29175    The Corrections
#
#    BookTitleSalesInDateRange
# 2                       3993
# 1                       3873
# 0                       3689
