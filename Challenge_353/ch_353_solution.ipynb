# %%
import pandas as pd
import json

# %%
#Read the CSV file contains the JSON data
trainer_df = pd.read_csv(r"C:\Users\LeLuu\Documents\Python_Practice\Challenge_353\pokemon_trainer.csv")

# %%
# Rename the column name,polemons to poke_data
trainer_df.rename(columns={'name,pokemons': 'poke_data'}, inplace=True)

# %%
#Analyze the JSON data in the poke_data column
#The trainer name text is in the first part of the string, and the pokemons are in the second part
trainer_df
# Out:
#                                            poke_data
# 0  "Ash",[{"pokemonNumber":1,"pokemonName":"Pikac...
# 1  "Brock",[{"pokemonNumber":1,"pokemonName":"Geo...
# 2  "Misty",[{"pokemonNumber":1,"pokemonName":"Hor...
# 3  "Amit",[{"pokemonNumber":1,"pokemonName":"Jolt...

# %% [markdown]
# ### Option 1: Split the text and then parse JSON and flatten
# - Step 1: Use REGEX to extract the data
# - Step 2: After getting the JSON structure, Parse it with json.loads
# - Step 3: Normalize the key-value pairs into each separate row
# - Step 4: Flatten the key-value pairs into separate columns
# - Step 5: Concatnate with the original data

# %%
#There are 2 options for parsing the JSON data
# 1. Use REGEX to extract the trainer name and pokemons. Then parse JSON to extract the pokemons.
trainer_df[['trainer_name', 'pokemons']] = trainer_df['poke_data'].str.extract(r'^"(.*?)",(.*)$')

# %%
trainer_df
# Out:
#                                            poke_data trainer_name  \
# 0  "Ash",[{"pokemonNumber":1,"pokemonName":"Pikac...          Ash
# 1  "Brock",[{"pokemonNumber":1,"pokemonName":"Geo...        Brock
# 2  "Misty",[{"pokemonNumber":1,"pokemonName":"Hor...        Misty
# 3  "Amit",[{"pokemonNumber":1,"pokemonName":"Jolt...         Amit
#
#                                             pokemons
# 0  [{"pokemonNumber":1,"pokemonName":"Pikachu"},{...
# 1  [{"pokemonNumber":1,"pokemonName":"Geodude"},{...
# 2  [{"pokemonNumber":1,"pokemonName":"Horsea"},{"...
# 3  [{"pokemonNumber":1,"pokemonName":"Jolteon"},{...

# %%
#Parse JSON data into the dictionary format in Python
trainer_df['pokemons'] = trainer_df['pokemons'].apply(json.loads)

# %%
#Normalize the key-value pairs in each object (inside the curly braces) in the pokemons column into a separate row
#Then each row contains one object (contains multiple key-value pairs)
normalize_pokemon_df = trainer_df.explode('pokemons')

# %%
#Flatten the pokemons column into separate columns (each key-value pair becomes a separate column)
normalize_pokemon_df['pokemons'].apply(pd.Series)
# Out:
#    pokemonNumber pokemonName
# 0              1     Pikachu
# 0              2  Butterfree
# 0              3   Pidgeotto
# 0              4   Bulbasaur
# 0              5   Charizard
# 0              6    Squirtle
# 1              1     Geodude
# 1              2     Chansey
# 1              3      Crobat
# 1              4      Vulpix
# 1              5  Forretress
# 1              6     Steelix
# 2              1      Horsea
# 2              2     Starmie
# 2              3     Goldeen
# 2              4     Togetic
# 2              5    Gyarados
# 2              6     Psyduck
# 3              1     Jolteon
# 3              2    Alakazam
# 3              3      Tauros
# 3              4    Gyarados
# 3              5      Gengar
# 3              6  Aerodactyl

# %%
# Concatenate the flattened columns with the original DataFrame
pd.concat([normalize_pokemon_df,normalize_pokemon_df['pokemons'].apply(pd.Series)],axis=1)
# Out:
#                                            poke_data trainer_name  \
# 0  "Ash",[{"pokemonNumber":1,"pokemonName":"Pikac...          Ash
# 0  "Ash",[{"pokemonNumber":1,"pokemonName":"Pikac...          Ash
# 0  "Ash",[{"pokemonNumber":1,"pokemonName":"Pikac...          Ash
# 0  "Ash",[{"pokemonNumber":1,"pokemonName":"Pikac...          Ash
# 0  "Ash",[{"pokemonNumber":1,"pokemonName":"Pikac...          Ash
# 0  "Ash",[{"pokemonNumber":1,"pokemonName":"Pikac...          Ash
# 1  "Brock",[{"pokemonNumber":1,"pokemonName":"Geo...        Brock
# 1  "Brock",[{"pokemonNumber":1,"pokemonName":"Geo...        Brock
# 1  "Brock",[{"pokemonNumber":1,"pokemonName":"Geo...        Brock
# 1  "Brock",[{"pokemonNumber":1,"pokemonName":"Geo...        Brock
# 1  "Brock",[{"pokemonNumber":1,"pokemonName":"Geo...        Brock
# 1  "Brock",[{"pokemonNumber":1,"pokemonName":"Geo...        Brock
# 2  "Misty",[{"pokemonNumber":1,"pokemonName":"Hor...        Misty
# 2  "Misty",[{"pokemonNumber":1,"pokemonName":"Hor...        Misty
# 2  "Misty",[{"pokemonNumber":1,"pokemonName":"Hor...        Misty
# 2  "Misty",[{"pokemonNumber":1,"pokemonName":"Hor...        Misty
# 2  "Misty",[{"pokemonNumber":1,"pokemonName":"Hor...        Misty
# 2  "Misty",[{"pokemonNumber":1,"pokemonName":"Hor...        Misty
# 3  "Amit",[{"pokemonNumber":1,"pokemonName":"Jolt...         Amit
# 3  "Amit",[{"pokemonNumber":1,"pokemonName":"Jolt...         Amit
# 3  "Amit",[{"pokemonNumber":1,"pokemonName":"Jolt...         Amit
# 3  "Amit",[{"pokemonNumber":1,"pokemonName":"Jolt...         Amit
# 3  "Amit",[{"pokemonNumber":1,"pokemonName":"Jolt...         Amit
# 3  "Amit",[{"pokemonNumber":1,"pokemonName":"Jolt...         Amit
#
#                                             pokemons  pokemonNumber  \
# 0     {'pokemonNumber': 1, 'pokemonName': 'Pikachu'}              1
# 0  {'pokemonNumber': 2, 'pokemonName': 'Butterfree'}              2
# 0   {'pokemonNumber': 3, 'pokemonName': 'Pidgeotto'}              3
# 0   {'pokemonNumber': 4, 'pokemonName': 'Bulbasaur'}              4
# 0   {'pokemonNumber': 5, 'pokemonName': 'Charizard'}              5
# 0    {'pokemonNumber': 6, 'pokemonName': 'Squirtle'}              6
# 1     {'pokemonNumber': 1, 'pokemonName': 'Geodude'}              1
# 1     {'pokemonNumber': 2, 'pokemonName': 'Chansey'}              2
# 1      {'pokemonNumber': 3, 'pokemonName': 'Crobat'}              3
# 1      {'pokemonNumber': 4, 'pokemonName': 'Vulpix'}              4
# 1  {'pokemonNumber': 5, 'pokemonName': 'Forretress'}              5
# 1     {'pokemonNumber': 6, 'pokemonName': 'Steelix'}              6
# 2      {'pokemonNumber': 1, 'pokemonName': 'Horsea'}              1
# 2     {'pokemonNumber': 2, 'pokemonName': 'Starmie'}              2
# 2     {'pokemonNumber': 3, 'pokemonName': 'Goldeen'}              3
# 2     {'pokemonNumber': 4, 'pokemonName': 'Togetic'}              4
# 2    {'pokemonNumber': 5, 'pokemonName': 'Gyarados'}              5
# 2     {'pokemonNumber': 6, 'pokemonName': 'Psyduck'}              6
# 3     {'pokemonNumber': 1, 'pokemonName': 'Jolteon'}              1
# 3    {'pokemonNumber': 2, 'pokemonName': 'Alakazam'}              2
# 3      {'pokemonNumber': 3, 'pokemonName': 'Tauros'}              3
# 3    {'pokemonNumber': 4, 'pokemonName': 'Gyarados'}              4
# 3      {'pokemonNumber': 5, 'pokemonName': 'Gengar'}              5
# 3  {'pokemonNumber': 6, 'pokemonName': 'Aerodactyl'}              6
#
#   pokemonName
# 0     Pikachu
# 0  Butterfree
# 0   Pidgeotto
# 0   Bulbasaur
# 0   Charizard
# 0    Squirtle
# 1     Geodude
# 1     Chansey
# 1      Crobat
# 1      Vulpix
# 1  Forretress
# 1     Steelix
# 2      Horsea
# 2     Starmie
# 2     Goldeen
# 2     Togetic
# 2    Gyarados
# 2     Psyduck
# 3     Jolteon
# 3    Alakazam
# 3      Tauros
# 3    Gyarados
# 3      Gengar
# 3  Aerodactyl

# %% [markdown]
# ### Option 2: Parse JSON and flatten data
# - Step 1: Initialize an empty array to store data
# - Step 2: Iterate to each row in the column, Add the square brackets outside of each row
# - Step 3: Parse JSON using json.loads function into dictionary for trainer and pokemons
# - Step 4: For each row after parsing, flatten each pokemon with the trainer name into separate row
# - Step 5: Store the data as a Pandas dataframe

# %%
#Option 2 is faster
# 2. Use the json.loads() method to parse the JSON string. But first, need to fix the string to make it valid JSON.
records = []

for row in trainer_df['poke_data']:
    # Step 1: Fix the string into valid JSO by wrapping it in square brackets
    valid_json = f"[{row}]"

    # Step 2: Parse as JSON list
    trainer_name, pokemons = json.loads(valid_json)

    # Step 3: Flatten each Pokémon with trainer name
    for p in pokemons:
        records.append({
            'trainer': trainer_name,
            'pokemonNumber': p['pokemonNumber'],
            'pokemonName': p['pokemonName']
        })

# %%
records
# Out:
# [{'trainer': 'Ash', 'pokemonNumber': 1, 'pokemonName': 'Pikachu'},
#  {'trainer': 'Ash', 'pokemonNumber': 2, 'pokemonName': 'Butterfree'},
#  {'trainer': 'Ash', 'pokemonNumber': 3, 'pokemonName': 'Pidgeotto'},
#  {'trainer': 'Ash', 'pokemonNumber': 4, 'pokemonName': 'Bulbasaur'},
#  {'trainer': 'Ash', 'pokemonNumber': 5, 'pokemonName': 'Charizard'},
#  {'trainer': 'Ash', 'pokemonNumber': 6, 'pokemonName': 'Squirtle'},
#  {'trainer': 'Brock', 'pokemonNumber': 1, 'pokemonName': 'Geodude'},
#  {'trainer': 'Brock', 'pokemonNumber': 2, 'pokemonName': 'Chansey'},
#  {'trainer': 'Brock', 'pokemonNumber': 3, 'pokemonName': 'Crobat'},
#  {'trainer': 'Brock', 'pokemonNumber': 4, 'pokemonName': 'Vulpix'},
#  {'trainer': 'Brock', 'pokemonNumber': 5, 'pokemonName': 'Forretress'},
#  {'trainer': 'Brock', 'pokemonNumber': 6, 'pokemonName': 'Steelix'},
#  {'trainer': 'Misty', 'pokemonNumber': 1, 'pokemonName': 'Horsea'},
#  {'trainer': 'Misty', 'pokemonNumber': 2, 'pokemonName': 'Starmie'},
#  {'trainer': 'Misty', 'pokemonNumber': 3, 'pokemonName': 'Goldeen'},
#  {'trainer': 'Misty', 'pokemonNumber': 4, 'pokemonName': 'Togetic'},
#  {'trainer': 'Misty', 'pokemonNumber': 5, 'pokemonName': 'Gyarados'},
#  {'trainer': 'Misty', 'pokemonNumber': 6, 'pokemonName': 'Psyduck'},
#  {'trainer': 'Amit', 'pokemonNumber': 1, 'pokemonName': 'Jolteon'},
#  {'trainer': 'Amit', 'pokemonNumber': 2, 'pokemonName': 'Alakazam'},
#  {'trainer': 'Amit', 'pokemonNumber': 3, 'pokemonName': 'Tauros'},
#  {'trainer': 'Amit', 'pokemonNumber': 4, 'pokemonName': 'Gyarados'},
#  {'trainer': 'Amit', 'pokemonNumber': 5, 'pokemonName': 'Gengar'},
#  {'trainer': 'Amit', 'pokemonNumber': 6, 'pokemonName': 'Aerodactyl'}]

# %%
records_df = pd.DataFrame(records)

# %%
records_df
# Out:
#    trainer  pokemonNumber pokemonName
# 0      Ash              1     Pikachu
# 1      Ash              2  Butterfree
# 2      Ash              3   Pidgeotto
# 3      Ash              4   Bulbasaur
# 4      Ash              5   Charizard
# 5      Ash              6    Squirtle
# 6    Brock              1     Geodude
# 7    Brock              2     Chansey
# 8    Brock              3      Crobat
# 9    Brock              4      Vulpix
# 10   Brock              5  Forretress
# 11   Brock              6     Steelix
# 12   Misty              1      Horsea
# 13   Misty              2     Starmie
# 14   Misty              3     Goldeen
# 15   Misty              4     Togetic
# 16   Misty              5    Gyarados
# 17   Misty              6     Psyduck
# 18    Amit              1     Jolteon
# 19    Amit              2    Alakazam
# 20    Amit              3      Tauros
# 21    Amit              4    Gyarados
# 22    Amit              5      Gengar
# 23    Amit              6  Aerodactyl

# %% [markdown]
# ## Add Other Dataset to get the type of Pokemon

# %%
pokedex_df = pd.read_csv(r"C:\Users\LeLuu\Documents\Python_Practice\Challenge_353\pokedex_(Update_05.20).csv")

# %%
pokedex_df
# Out:
#       Unnamed: 0  pokedex_number                            name german_name  \
# 0              0               1                       Bulbasaur     Bisasam
# 1              1               2                         Ivysaur   Bisaknosp
# 2              2               3                        Venusaur    Bisaflor
# 3              3               3                   Mega Venusaur    Bisaflor
# 4              4               4                      Charmander    Glumanda
# ...          ...             ...                             ...         ...
# 1023        1023             888     Zacian Hero of Many Battles         NaN
# 1024        1024             889        Zamazenta Crowned Shield         NaN
# 1025        1025             889  Zamazenta Hero of Many Battles         NaN
# 1026        1026             890                       Eternatus         NaN
# 1027        1027             890             Eternatus Eternamax         NaN
#
#             japanese_name  generation     status           species  \
# 0     フシギダネ (Fushigidane)           1     Normal      Seed Pokémon
# 1      フシギソウ (Fushigisou)           1     Normal      Seed Pokémon
# 2     フシギバナ (Fushigibana)           1     Normal      Seed Pokémon
# 3     フシギバナ (Fushigibana)           1     Normal      Seed Pokémon
# 4         ヒトカゲ (Hitokage)           1     Normal    Lizard Pokémon
# ...                   ...         ...        ...               ...
# 1023                  NaN           8  Legendary   Warrior Pokémon
# 1024                  NaN           8  Legendary   Warrior Pokémon
# 1025                  NaN           8  Legendary   Warrior Pokémon
# 1026                  NaN           8  Legendary  Gigantic Pokémon
# 1027                  NaN           8  Legendary  Gigantic Pokémon
#
#       type_number    type_1  ... against_ground  against_flying  \
# 0               2     Grass  ...            1.0             2.0
# 1               2     Grass  ...            1.0             2.0
# 2               2     Grass  ...            1.0             2.0
# 3               2     Grass  ...            1.0             2.0
# 4               1      Fire  ...            2.0             1.0
# ...           ...       ...  ...            ...             ...
# 1023            1     Fairy  ...            1.0             1.0
# 1024            2  Fighting  ...            2.0             1.0
# 1025            1  Fighting  ...            1.0             2.0
# 1026            2    Poison  ...            2.0             1.0
# 1027            2    Poison  ...            2.0             1.0
#
#       against_psychic  against_bug against_rock against_ghost against_dragon  \
# 0                 2.0         1.00         1.00           1.0            1.0
# 1                 2.0         1.00         1.00           1.0            1.0
# 2                 2.0         1.00         1.00           1.0            1.0
# 3                 2.0         1.00         1.00           1.0            1.0
# 4                 1.0         0.50         2.00           1.0            1.0
# ...               ...          ...          ...           ...            ...
# 1023              1.0         0.50         1.00           1.0            0.0
# 1024              1.0         0.25         0.25           1.0            0.5
# 1025              2.0         0.50         0.50           1.0            1.0
# 1026              2.0         0.50         1.00           1.0            2.0
# 1027              2.0         0.50         1.00           1.0            2.0
#
#       against_dark  against_steel  against_fairy
# 0              1.0            1.0            0.5
# 1              1.0            1.0            0.5
# 2              1.0            1.0            0.5
# 3              1.0            1.0            0.5
# 4              1.0            0.5            0.5
# ...            ...            ...            ...
# 1023           0.5            2.0            1.0
# 1024           0.5            0.5            1.0
# 1025           0.5            1.0            2.0
# 1026           1.0            1.0            1.0
# 1027           1.0            1.0            1.0
#
# [1028 rows x 51 columns]

# %%
#Inner join with the records_df and pokedex_df on the pokemonName column to mapping the type of each Pokémon
merge_df = pd.merge(left=records_df, right=pokedex_df, left_on='pokemonName' , right_on='name',how='inner')

# %%
#List of columns to keep in the final DataFrame
columns_to_keep = ['trainer', 'pokemonNumber', 'pokemonName','type_1', 'type_2']

# %%
merge_df= merge_df[columns_to_keep]

# %%
merge_df
# Out:
#    trainer  pokemonNumber pokemonName    type_1   type_2
# 0      Ash              1     Pikachu  Electric      NaN
# 1      Ash              2  Butterfree       Bug   Flying
# 2      Ash              3   Pidgeotto    Normal   Flying
# 3      Ash              4   Bulbasaur     Grass   Poison
# 4      Ash              5   Charizard      Fire   Flying
# 5      Ash              6    Squirtle     Water      NaN
# 6    Brock              1     Geodude      Rock   Ground
# 7    Brock              2     Chansey    Normal      NaN
# 8    Brock              3      Crobat    Poison   Flying
# 9    Brock              4      Vulpix      Fire      NaN
# 10   Brock              5  Forretress       Bug    Steel
# 11   Brock              6     Steelix     Steel   Ground
# 12   Misty              1      Horsea     Water      NaN
# 13   Misty              2     Starmie     Water  Psychic
# 14   Misty              3     Goldeen     Water      NaN
# 15   Misty              4     Togetic     Fairy   Flying
# 16   Misty              5    Gyarados     Water   Flying
# 17   Misty              6     Psyduck     Water      NaN
# 18    Amit              1     Jolteon  Electric      NaN
# 19    Amit              2    Alakazam   Psychic      NaN
# 20    Amit              3      Tauros    Normal      NaN
# 21    Amit              4    Gyarados     Water   Flying
# 22    Amit              5      Gengar     Ghost   Poison
# 23    Amit              6  Aerodactyl      Rock   Flying

# %%
# Add the 2 column types to the list of types
merge_df['types'] = merge_df[['type_1', 'type_2']].values.tolist()

# %%
merge_df
# Out:
#    trainer  pokemonNumber pokemonName    type_1   type_2             types
# 0      Ash              1     Pikachu  Electric      NaN   [Electric, nan]
# 1      Ash              2  Butterfree       Bug   Flying     [Bug, Flying]
# 2      Ash              3   Pidgeotto    Normal   Flying  [Normal, Flying]
# 3      Ash              4   Bulbasaur     Grass   Poison   [Grass, Poison]
# 4      Ash              5   Charizard      Fire   Flying    [Fire, Flying]
# 5      Ash              6    Squirtle     Water      NaN      [Water, nan]
# 6    Brock              1     Geodude      Rock   Ground    [Rock, Ground]
# 7    Brock              2     Chansey    Normal      NaN     [Normal, nan]
# 8    Brock              3      Crobat    Poison   Flying  [Poison, Flying]
# 9    Brock              4      Vulpix      Fire      NaN       [Fire, nan]
# 10   Brock              5  Forretress       Bug    Steel      [Bug, Steel]
# 11   Brock              6     Steelix     Steel   Ground   [Steel, Ground]
# 12   Misty              1      Horsea     Water      NaN      [Water, nan]
# 13   Misty              2     Starmie     Water  Psychic  [Water, Psychic]
# 14   Misty              3     Goldeen     Water      NaN      [Water, nan]
# 15   Misty              4     Togetic     Fairy   Flying   [Fairy, Flying]
# 16   Misty              5    Gyarados     Water   Flying   [Water, Flying]
# 17   Misty              6     Psyduck     Water      NaN      [Water, nan]
# 18    Amit              1     Jolteon  Electric      NaN   [Electric, nan]
# 19    Amit              2    Alakazam   Psychic      NaN    [Psychic, nan]
# 20    Amit              3      Tauros    Normal      NaN     [Normal, nan]
# 21    Amit              4    Gyarados     Water   Flying   [Water, Flying]
# 22    Amit              5      Gengar     Ghost   Poison   [Ghost, Poison]
# 23    Amit              6  Aerodactyl      Rock   Flying    [Rock, Flying]

# %%
#Removing the None values from the types list
merge_df['types'] = merge_df['types'].apply(lambda x: [t for t in x if pd.notna(t)])

# %%
merge_df
# Out:
#    trainer  pokemonNumber pokemonName    type_1   type_2             types
# 0      Ash              1     Pikachu  Electric      NaN        [Electric]
# 1      Ash              2  Butterfree       Bug   Flying     [Bug, Flying]
# 2      Ash              3   Pidgeotto    Normal   Flying  [Normal, Flying]
# 3      Ash              4   Bulbasaur     Grass   Poison   [Grass, Poison]
# 4      Ash              5   Charizard      Fire   Flying    [Fire, Flying]
# 5      Ash              6    Squirtle     Water      NaN           [Water]
# 6    Brock              1     Geodude      Rock   Ground    [Rock, Ground]
# 7    Brock              2     Chansey    Normal      NaN          [Normal]
# 8    Brock              3      Crobat    Poison   Flying  [Poison, Flying]
# 9    Brock              4      Vulpix      Fire      NaN            [Fire]
# 10   Brock              5  Forretress       Bug    Steel      [Bug, Steel]
# 11   Brock              6     Steelix     Steel   Ground   [Steel, Ground]
# 12   Misty              1      Horsea     Water      NaN           [Water]
# 13   Misty              2     Starmie     Water  Psychic  [Water, Psychic]
# 14   Misty              3     Goldeen     Water      NaN           [Water]
# 15   Misty              4     Togetic     Fairy   Flying   [Fairy, Flying]
# 16   Misty              5    Gyarados     Water   Flying   [Water, Flying]
# 17   Misty              6     Psyduck     Water      NaN           [Water]
# 18    Amit              1     Jolteon  Electric      NaN        [Electric]
# 19    Amit              2    Alakazam   Psychic      NaN         [Psychic]
# 20    Amit              3      Tauros    Normal      NaN          [Normal]
# 21    Amit              4    Gyarados     Water   Flying   [Water, Flying]
# 22    Amit              5      Gengar     Ghost   Poison   [Ghost, Poison]
# 23    Amit              6  Aerodactyl      Rock   Flying    [Rock, Flying]

# %%
#Use set for the types column to get unique types for each trainer
pokemon_type_by_trainer = merge_df.groupby('trainer')['types'].sum().apply(set).reset_index()

# %%
pokemon_type_by_trainer
# Out:
#   trainer                                              types
# 0    Amit  {Water, Psychic, Electric, Rock, Ghost, Poison...
# 1     Ash  {Water, Bug, Electric, Poison, Normal, Flying,...
# 2   Brock  {Bug, Rock, Steel, Poison, Normal, Ground, Fly...
# 3   Misty                    {Flying, Water, Psychic, Fairy}

# %%
#Count how many unique types each trainer has
pokemon_type_by_trainer['count_types'] = pokemon_type_by_trainer['types'].apply(len)

# %%
pokemon_type_by_trainer
# Out:
#   trainer                                              types  count_types
# 0    Amit  {Water, Psychic, Electric, Rock, Ghost, Poison...            8
# 1     Ash  {Water, Bug, Electric, Poison, Normal, Flying,...            8
# 2   Brock  {Bug, Rock, Steel, Poison, Normal, Ground, Fly...            8
# 3   Misty                    {Flying, Water, Psychic, Fairy}            4

# %%
#Qualified trainers are those who have at least 6 unique types
qualified_trainers = pokemon_type_by_trainer[pokemon_type_by_trainer['count_types'] >= 6]

# %%
qualified_trainers
# Out:
#   trainer                                              types  count_types
# 0    Amit  {Water, Psychic, Electric, Rock, Ghost, Poison...            8
# 1     Ash  {Water, Bug, Electric, Poison, Normal, Flying,...            8
# 2   Brock  {Bug, Rock, Steel, Poison, Normal, Ground, Fly...            8

# %%
#Merge the qualified trainers with the records_df to filter only qualified trainers' Pokémon with their pokemons name
final_df = pd.merge(left=qualified_trainers, right=records_df, on='trainer', how='inner')[['trainer', 'pokemonName', 'pokemonNumber']]

# %%
final_df
# Out:
#    trainer pokemonName  pokemonNumber
# 0     Amit     Jolteon              1
# 1     Amit    Alakazam              2
# 2     Amit      Tauros              3
# 3     Amit    Gyarados              4
# 4     Amit      Gengar              5
# 5     Amit  Aerodactyl              6
# 6      Ash     Pikachu              1
# 7      Ash  Butterfree              2
# 8      Ash   Pidgeotto              3
# 9      Ash   Bulbasaur              4
# 10     Ash   Charizard              5
# 11     Ash    Squirtle              6
# 12   Brock     Geodude              1
# 13   Brock     Chansey              2
# 14   Brock      Crobat              3
# 15   Brock      Vulpix              4
# 16   Brock  Forretress              5
# 17   Brock     Steelix              6

# %%
#Final step, pivot all Pokemon names for each trainer into a single row
final_ans = final_df.pivot(index='trainer',columns='pokemonNumber', values='pokemonName')

# %%
final_ans
# Out:
# pokemonNumber        1           2          3          4           5  \
# trainer
# Amit           Jolteon    Alakazam     Tauros   Gyarados      Gengar
# Ash            Pikachu  Butterfree  Pidgeotto  Bulbasaur   Charizard
# Brock          Geodude     Chansey     Crobat     Vulpix  Forretress
#
# pokemonNumber           6
# trainer
# Amit           Aerodactyl
# Ash              Squirtle
# Brock             Steelix

# %%
#Rename the columns by adding Pokmon prefix
final_ans.columns = [f'Pokemon {col}' for col in final_ans.columns]

# %%
final_ans.reset_index(inplace=True)

# %%
final_ans
# Out:
#   trainer Pokemon 1   Pokemon 2  Pokemon 3  Pokemon 4   Pokemon 5   Pokemon 6
# 0    Amit   Jolteon    Alakazam     Tauros   Gyarados      Gengar  Aerodactyl
# 1     Ash   Pikachu  Butterfree  Pidgeotto  Bulbasaur   Charizard    Squirtle
# 2   Brock   Geodude     Chansey     Crobat     Vulpix  Forretress     Steelix
